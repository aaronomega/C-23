# %% [markdown]
# <a href="https://colab.research.google.com/github/aaronomega/C-23/blob/main/healthcarecapstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Identify the shape of the dataset
import pandas as pd
df = pd.read_csv("/content/health care diabetes.csv")
df1 = pd.read_csv("/content/health care diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
bd=df["Pregnancies"].value_counts()

# %%
c=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
sns.histplot(df["Glucose"])
# Out:
# <Axes: xlabel='Glucose', ylabel='Count'>

# %%
sns.histplot(df["BloodPressure"])
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Count'>

# %%
sns.histplot(df["SkinThickness"])
# Out:
# <Axes: xlabel='SkinThickness', ylabel='Count'>

# %%
sns.histplot(df["BMI"])
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df1["Glucose"] = df["Glucose"].replace(0,120)
df1["BloodPressure"] = df["BloodPressure"].replace(0,70)
df1["SkinThickness"] = df["SkinThickness"].replace(0,21)
df1["Insulin"] = df["Insulin"].replace(0,79)
df1["BMI"] = df["BMI"].replace(0,32.00)

# %%
df1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.675781      72.295573      26.743490  118.270833
# std       3.369578   30.436252      12.106756       9.546733   93.243829
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      21.000000   79.000000
# 50%       3.000000  117.000000      72.000000      23.000000   79.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450911                  0.471876   33.240885    0.348958
# std      6.875366                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df1['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
sns.pairplot(df1,hue='Outcome',kind= 'scatter',diag_kind="kde",palette="deep")

# %%
corr=df1.corr()

# %%
sns.heatmap(corr, annot=True, fmt=".2f", cmap='Spectral', square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %% [markdown]
# WEEK 3:

# %%
x = df.drop('Outcome',axis=1)
y = df.Outcome

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=101)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.linear_model import LogisticRegression
le = LogisticRegression(max_iter = 500)
le.fit(x_train,y_train)
y_pred = le.predict(x_test)
ac_le = accuracy_score(y_test,y_pred)
print("Accuracy of Logistic Regression Model:",ac_le)
print("Confusion Matrix of Logistic Regression Model:\n",confusion_matrix(y_test,y_pred))
print("Classification report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy of Logistic Regression Model: 0.7922077922077922
# Confusion Matrix of Logistic Regression Model:
#  [[89 14]
#  [18 33]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85       103
#            1       0.70      0.65      0.67        51
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.76      0.76       154
# weighted avg       0.79      0.79      0.79       154

# %%
from sklearn.metrics import roc_curve,roc_auc_score
le_probs = le.predict_proba(x_test)
le_probs = le_probs[:,1]
le_auc= roc_auc_score(y_test,le_probs)
le_fpr,le_tpr,thresholds  = roc_curve(y_test,le_probs)
print("AUC",le_auc)
# Out:
# AUC 0.8501808490386445

# %%
from sklearn.naive_bayes import GaussianNB
nb =  GaussianNB()
nb.fit(x_train,y_train)
y_pred = nb.predict(x_test)
ac_nb = accuracy_score(y_test,y_pred)
print("Accuracy of Naive Bayes Model:",ac_nb)
print("Confusion Matrix of Naive Bayes Model:\n",confusion_matrix(y_test,y_pred))
print("Classification report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy of Naive Bayes Model: 0.7532467532467533
# Confusion Matrix of Naive Bayes Model:
#  [[83 20]
#  [18 33]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81       103
#            1       0.62      0.65      0.63        51
#
#     accuracy                           0.75       154
#    macro avg       0.72      0.73      0.72       154
# weighted avg       0.76      0.75      0.75       154

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_acclist = []
for K in range(21):
    K += 1
    knn= KNeighborsClassifier(n_neighbors =K)
    knn.fit(x_train,y_train)
    knn_pred = knn.predict(x_test)
    knn_results = confusion_matrix(y_test,knn_pred)
    knn_score = accuracy_score(y_test,knn_pred)
    print("The accuracy of KNN model for k",K,"is:%0.4f"%knn_score)
    print("Confusion Matrix :\n", knn_results)
    knn_acclist.append(knn_score)
ac_knn = max(knn_acclist)
print("Maximum Accuracy using KNN Model: %0.4f"%ac_knn)
# Out:
# The accuracy of KNN model for k 1 is:0.6429
# Confusion Matrix :
#  [[76 27]
#  [28 23]]
# The accuracy of KNN model for k 2 is:0.7078
# Confusion Matrix :
#  [[93 10]
#  [35 16]]
# The accuracy of KNN model for k 3 is:0.7143
# Confusion Matrix :
#  [[83 20]
#  [24 27]]
# The accuracy of KNN model for k 4 is:0.7532
# Confusion Matrix :
#  [[94  9]
#  [29 22]]
# The accuracy of KNN model for k 5 is:0.7597
# Confusion Matrix :
#  [[87 16]
#  [21 30]]
# The accuracy of KNN model for k 6 is:0.7468
# Confusion Matrix :
#  [[90 13]
#  [26 25]]
# The accuracy of KNN model for k 7 is:0.7338
# Confusion Matrix :
#  [[85 18]
#  [23 28]]
# The accuracy of KNN model for k 8 is:0.7468
# Confusion Matrix :
#  [[89 14]
#  [25 26]]
# The accuracy of KNN model for k 9 is:0.7597
# Confusion Matrix :
#  [[87 16]
#  [21 30]]
# The accuracy of KNN model for k 10 is:0.7597
# Confusion Matrix :
#  [[89 14]
#  [23 28]]
# The accuracy of KNN model for k 11 is:0.7597
# Confusion Matrix :
#  [[86 17]
#  [20 31]]
# The accuracy of KNN model for k 12 is:0.7532
# Confusion Matrix :
#  [[89 14]
#  [24 27]]
# The accuracy of KNN model for k 13 is:0.7403
# Confusion Matrix :
#  [[84 19]
#  [21 30]]
# The accuracy of KNN model for k 14 is:0.7597
# Confusion Matrix :
#  [[89 14]
#  [23 28]]
# The accuracy of KNN model for k 15 is:0.7403
# Confusion Matrix :
#  [[86 17]
#  [23 28]]
# The accuracy of KNN model for k 16 is:0.7597
# Confusion Matrix :
#  [[90 13]
#  [24 27]]
# The accuracy of KNN model for k 17 is:0.7468
# Confusion Matrix :
#  [[86 17]
#  [22 29]]
# The accuracy of KNN model for k 18 is:0.7532
# Confusion Matrix :
#  [[89 14]
#  [24 27]]
# The accuracy of KNN model for k 19 is:0.7532
# Confusion Matrix :
#  [[86 17]
#  [21 30]]
# The accuracy of KNN model for k 20 is:0.7597
# Confusion Matrix :
#  [[90 13]
#  [24 27]]
# The accuracy of KNN model for k 21 is:0.7468
# Confusion Matrix :
#  [[88 15]
#  [24 27]]
# Maximum Accuracy using KNN Model: 0.7597

# %%
knn_probs = knn.predict_proba(x_test)
knn_probs = knn_probs[:,1]
knn_auc= roc_auc_score(y_test,knn_probs)
knn_fpr,knn_tpr,thresholds  = roc_curve(y_test,knn_probs)
print("Classification report:\n",classification_report(y_test,y_pred))
print("AUC",knn_auc)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81       103
#            1       0.62      0.65      0.63        51
#
#     accuracy                           0.75       154
#    macro avg       0.72      0.73      0.72       154
# weighted avg       0.76      0.75      0.75       154
#
# AUC 0.8140110413097278

# %%
from sklearn.ensemble import RandomForestClassifier
re = RandomForestClassifier(n_estimators=20)
re.fit(x_train,y_train)
y_pred = re.predict(x_test)
ac_re = accuracy_score(y_test,y_pred)
print("Accuracy of Random Forest Classifier:",ac_re)
print("Confusion Matrix of Random Forest Classifier:\n",confusion_matrix(y_test,y_pred))
print("Classification report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy of Random Forest Classifier: 0.7792207792207793
# Confusion Matrix of Random Forest Classifier:
#  [[91 12]
#  [22 29]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       103
#            1       0.71      0.57      0.63        51
#
#     accuracy                           0.78       154
#    macro avg       0.76      0.73      0.74       154
# weighted avg       0.77      0.78      0.77       154

# %%
rdc_probs = re.predict_proba(x_test)
rdc_probs = rdc_probs[:,1]
rdc_auc= roc_auc_score(y_test,knn_probs)
rdc_fpr,rdc_tpr,thresholds  = roc_curve(y_test,rdc_probs)
print("AUC",rdc_auc)
# Out:
# AUC 0.8140110413097278

# %%
from sklearn.svm import SVC
sv = SVC(kernel='rbf', C=1e9, gamma=1e-07,probability=True,)
sv.fit(x_train,y_train)
y_pred = sv.predict(x_test)
ac_sv = accuracy_score(y_test,y_pred)
print("Accuracy of Support Vendor Machine:",ac_sv)
print("Confusion Matrix of Support Vendor Machine :\n",confusion_matrix(y_test,y_pred))
print("Classification report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy of Support Vendor Machine: 0.7727272727272727
# Confusion Matrix of Support Vendor Machine :
#  [[90 13]
#  [22 29]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84       103
#            1       0.69      0.57      0.62        51
#
#     accuracy                           0.77       154
#    macro avg       0.75      0.72      0.73       154
# weighted avg       0.77      0.77      0.77       154

# %%
svm_probs = sv.predict_proba(x_test)
svm_probs = svm_probs[:,1]
svm_auc= roc_auc_score(y_test,svm_probs)
svm_fpr,svm_tpr,thresholds  = roc_curve(y_test,svm_probs)
print("AUC",svm_auc)
# Out:
# AUC 0.8459927660384543

# %%
nb_probs = nb.predict_proba(x_test)
nb_probs = nb_probs[:,1]
nb_auc= roc_auc_score(y_test,nb_probs)
nb_fpr,nb_tpr,thresholds  = roc_curve(y_test,nb_probs)
print("AUC",nb_auc)
# Out:
# AUC 0.81305920426423

# %%
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
plt.subplots(figsize=(10,10))
plt.plot(p_fpr, p_tpr, color ='black',lw=2,linestyle= '--')
plt.plot(rdc_fpr,rdc_tpr, color = 'red',lw=2,linestyle= '--',label='Logistic Regression')
plt.plot(nb_fpr,nb_tpr, color = 'orange',lw=2,linestyle= '--',label='Naive Bayes')
plt.plot(knn_fpr,knn_tpr, color = 'yellow',lw=2,linestyle= '--',label='KNN')
plt.plot(rdc_fpr,rdc_tpr, color = 'green',lw=2,linestyle= '--',label='SVM')
plt.plot(svm_fpr,svm_tpr, color = 'blue',lw=2,linestyle= '--',label='SVM')
plt.title('AUC(ROC curve)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()
